# %% [markdown]
# # Centriole marker collocalization analysis
#
# This notebook would mostly focus on the analysis of the position centrioles markers. The goal is to determine whether Centrin2 and CenSpark label the same centriole, meaning that they have the same position (the centriole position).
